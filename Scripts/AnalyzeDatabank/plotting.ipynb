# %%
import yaml

# %%
BMRBid = '50115'

dataFolder = '../../Data/Simulations/tst/'
spin_relaxation_time_file = dataFolder + 'spin_relaxation_times.yaml'

with open(spin_relaxation_time_file, "r") as file:
    spin_relaxation_times = yaml.safe_load(file)
    
exp_data_path = '../../Data/Experiments/spin_relaxation/BMRBid' + BMRBid
experimental_spin_relaxation_times_file = exp_data_path + '/spin_relaxation_times.yaml'
with open(experimental_spin_relaxation_times_file, 'r') as file:
    exp_spin_relaxation_times = yaml.safe_load(file)

# %%
import matplotlib.pyplot as plt

# Your data
data = exp_spin_relaxation_times

# Sort data by residue index (assumes residue name starts with a number)
sorted_items = sorted(data.items(), key=lambda x: int(''.join(filter(str.isdigit, x[0]))))

# Extract residue names and values
residues_exp = [res for res, _ in sorted_items]
T1_values_exp = [vals['T1']['value'] if 'T1' in vals else float('nan') for _, vals in sorted_items]
T2_values_exp = [vals['T2']['value'] if 'T2' in vals else float('nan') for _, vals in sorted_items]
hetNOE_values_exp = [vals['hetNOE']['value'] if 'hetNOE' in vals else float('nan') for _, vals in sorted_items]

# Your data
data = spin_relaxation_times

# Sort data by residue index (assumes residue name starts with a number)
sorted_items = sorted(data.items(), key=lambda x: int(''.join(filter(str.isdigit, x[0]))))

# Extract residue names and values
residues = [res for res, _ in sorted_items]
ind = 0
for i in residues:
    residues[ind] = residues[ind].replace('HIP','HIS')
    ind +=1
T1_values = [vals['T1'] if 'T1' in vals else float('nan') for _, vals in sorted_items]
T2_values = [vals['T2'] if 'T2' in vals else float('nan') for _, vals in sorted_items]
hetNOE_values = [vals['hetNOE'] if 'hetNOE' in vals else float('nan') for _, vals in sorted_items]


# Plotting
fig, axs = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

axs[0].plot(residues, T1_values, marker='o', color='red')
axs[0].plot(residues_exp, T1_values_exp, marker='o', color='black')
axs[0].set_ylabel('T1')
axs[0].set_title('T1 Relaxation Times')

axs[1].plot(residues, T2_values, marker='o', color='red')
axs[1].plot(residues_exp, T2_values_exp, marker='o', color='black')
axs[1].set_ylabel('T2')
axs[1].set_title('T2 Relaxation Times')

axs[2].plot(residues, hetNOE_values, marker='o', color='red')
axs[2].plot(residues_exp, hetNOE_values_exp, marker='o', color='black')
axs[2].set_ylabel('hetNOE')
axs[2].set_title('hetNOE Values')
axs[2].set_xticks(range(len(residues)))
axs[2].set_xticklabels(residues, rotation=90)

plt.tight_layout()
plt.show()
# Out:
# /home/sosamuli/.local/lib/python3.10/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
print(exp_spin_relaxation_times)
# Out:
# {'11HIS': {800.0: {'hetNOE': {'error': 0.0547767, 'value': 0.171034217}}}, '12THR': {800.0: {'T1': {'error': 0.01324, 'value': 0.59736}, 'T2': {'error': 0.015550000000000001, 'value': 0.21080000000000002}, 'hetNOE': {'error': 0.003080989, 'value': 0.324830027}}}, '14ASP': {800.0: {'T1': {'error': 0.00777, 'value': 0.58397}, 'T2': {'error': 0.00666, 'value': 0.1825}, 'hetNOE': {'error': 0.001042116, 'value': 0.295022684}}}, '16LEU': {800.0: {'T1': {'error': 0.01007, 'value': 0.55062}, 'T2': {'error': 0.00608, 'value': 0.22249000000000002}, 'hetNOE': {'error': 0.001775605, 'value': 0.421153605}}}, '17ASN': {800.0: {'T1': {'error': 0.008039999999999999, 'value': 0.5442400000000001}, 'T2': {'error': 0.009519999999999999, 'value': 0.21165}, 'hetNOE': {'error': 0.000304873, 'value': 0.425169246}}}, '18LEU': {800.0: {'T1': {'error': 0.0074600000000000005, 'value': 0.57221}, 'T2': {'error': 0.00878, 'value': 0.19269}, 'hetNOE': {'error': 0.00063961, 'value': 0.323108998}}}, '19ARG': {800.0: {'T1': {'error': 0.00657, 'value': 0.56216}, 'T2': {'error': 0.0087, 'value': 0.24805000000000002}, 'hetNOE': {'error': 0.005768456, 'value': 0.381970335}}}, '20GLY': {800.0: {'T1': {'error': 0.00638, 'value': 0.59301}, 'T2': {'error': 0.012740000000000001, 'value': 0.26039}, 'hetNOE': {'error': 0.004643777, 'value': 0.269921243}}}, '22LEU': {800.0
sorted_items = sorted(data.items(), key=lambda x: int(''.join(filter(str.isdigit, x[0]))))

# Extract residue names and values
residues = [res for res, _ in sorted_items]
ind = 0
for i in residues:
    residues[ind] = residues[ind].replace('HIP','HIS')
    ind +=1
T1_values = [1 / vals['T1'] if 'T1' in vals else float('nan') for _, vals in sorted_items]
T2_values = [1 / vals['T2'] if 'T2' in vals else float('nan') for _, vals in sorted_items]
hetNOE_values = [vals['hetNOE'] if 'hetNOE' in vals else float('nan') for _, vals in sorted_items]


# Plotting
fig, axs = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

axs[0].plot(residues, T1_values, marker='o', color='red')
axs[0].plot(residues_exp, T1_values_exp, marker='o', color='black')
axs[0].set_ylabel('R1')
axs[0].set_title('R1 Relaxation Rates')

axs[1].plot(residues, T2_values, marker='o', color='red')
axs[1].plot(residues_exp, T2_values_exp, marker='o', color='black')
axs[1].set_ylabel('R2')
axs[1].set_title('R2 Relaxation Rates')

axs[2].plot(residues, hetNOE_values, marker='o', color='red')
axs[2].plot(residues_exp, hetNOE_values_exp, marker='o', color='black')
axs[2].set_ylabel('hetNOE')
axs[2].set_title('hetNOE Values')
axs[2].set_xticks(range(len(residues)))
axs[2].set_xticklabels(residues, rotation=90)

plt.tight_layout()
plt.show()

# %%
print(residues)

#print(residues.index)

ind = 0
for i in residues:
    residues[ind] = residues[ind].replace('HIP','HIS')
    ind +=1

print(residues)    

print(residues_exp)
print(hetNOE_values)
# Out:
# ['2ASN', '3ALA', '4MET', '5THR', '7VAL', '8ARG', '11HIS', '12THR', '14ASP', '16LEU', '17ASN', '18LEU', '19ARG', '20GLY', '22LEU', '23ASP', '24GLY', '26ARG', '27TRP', '28ARG', '29ARG', '30ALA', '31GLU', '33ALA', '34GLN', '35SER', '36ARG', '37ARG', '39GLY', '40ARG', '41SER', '42ARG', '44GLY', '45GLY', '46ALA', '48LEU', '49ARG', '50TYR', '51HIS', '52ARG', '53THR', '54GLY', '55VAL', '56GLY', '57MET', '58SER', '59ARG', '60THR', '61GLY', '62HIS', '63GLY', '64SER', '65ARG', '67VAL']
# ['2ASN', '3ALA', '4MET', '5THR', '7VAL', '8ARG', '11HIS', '12THR', '14ASP', '16LEU', '17ASN', '18LEU', '19ARG', '20GLY', '22LEU', '23ASP', '24GLY', '26ARG', '27TRP', '28ARG', '29ARG', '30ALA', '31GLU', '33ALA', '34GLN', '35SER', '36ARG', '37ARG', '39GLY', '40ARG', '41SER', '42ARG', '44GLY', '45GLY', '46ALA', '48LEU', '49ARG', '50TYR', '51HIS', '52ARG', '53THR', '54GLY', '55VAL', '56GLY', '57MET', '58SER', '59ARG', '60THR', '61GLY', '62HIS', '63GLY', '64SER', '65ARG', '67VAL']
# ['3ALA', '4MET', '5THR', '7VAL', '8ARG', '11HIS', '12THR', '14ASP', '16LEU', '17ASN', '18LEU', '19ARG', '20GLY', '22LEU', '23ASP', '24GLY', '26ARG', '27TRP', '28ARG', '29ARG', '30ALA', '31GLU', '33ALA', '34GLN', '35SER', '36ARG', '37ARG', '39GLY', '40ARG', '41SER', '42ARG', '44GLY', '45GLY', '46ALA', '48LEU', '49ARG', '50TYR', '51HIS', '52ARG', '53THR', '54GLY', '55VAL', '56GLY', '57MET', '58SER', '59ARG', '60THR', '61GLY', '63GLY', '64SER', '65ARG', '67VAL']
# [-1.9369540549267295, -1.4451899981930714, -1.1975363684570763, -0.7679258146842785, -0.4186625400836985, -0.20094484042776495, 0.1406962502790189, 0.23738428719489613, 0.4137431686263623, 0.4581636043235514, 0.34901880627545256, 0.3114187657682208, 0.26072635473152694, 0.16765101825865036, 0.09234647156690934, 0.0715032560746458, 0.023509211920308304, 0.17301089001356307, 0.1890953301225422, 0.23059530083653812, 0.24921887074148708, 0.2428280155921394, 0.22202596624794102, 0.21150676922059175, 0.21277136691801957, 0.16474065857114417, 0.13258907790232433, 0.04633616968343546, -0.02790909760450644, -0.2082448512367736, -0.1842729243227692, -0.17670398270747034, -0.2520390760897375, -0.5079904161897248, -0.2605775956712728, -0.35659729162874454, -0.14017691723030867, -0.1545678302189344, -0.1898888006165389, -0.14048006797472312, -0.1933643442082984, -0.3332335060890821, -0.32940338876432285, -0.4711121292232996, -0.28817957166959185, -0.40175472974964954, -0.37196229673671244, -0.401513774570992, -0.46173689534076856, -0.6380388626887454, -0.7018999958005592, -0.7242498231072956, -0.7139932949215946, -1.0804956301831172]

# %%
# Sort data by numeric residue index
sorted_items = sorted(data.items(), key=lambda x: int(''.join(filter(str.isdigit, x[0]))))

# Extract residue names and inverse values
residues = [res for res, _ in sorted_items]
R1_values = [1.0 / vals['T1']['value'] if 'T1' in vals else float('nan') for _, vals in sorted_items]
R2_values = [1.0 / vals['T2']['value'] if 'T2' in vals else float('nan') for _, vals in sorted_items]
hetNOE_values = [vals['hetNOE']['value'] if 'hetNOE' in vals else float('nan') for _, vals in sorted_items]

# Plotting
fig, axs = plt.subplots(3, 1, figsize=(14, 10), sharex=True)

axs[0].plot(residues, R1_values, marker='o', color='blue')
axs[0].set_ylabel('R1 (1/s)')
axs[0].set_title('R1 Relaxation Rates (1/T1)')

axs[1].plot(residues, R2_values, marker='o', color='green')
axs[1].set_ylabel('R2 (1/s)')
axs[1].set_title('R2 Relaxation Rates (1/T2)')

axs[2].plot(residues, hetNOE_values, marker='o', color='red')
axs[2].set_ylabel('hetNOE')
axs[2].set_title('hetNOE Values')
axs[2].set_xticks(range(len(residues)))
axs[2].set_xticklabels(residues, rotation=90)

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_168986/2456915880.py in <module>
#       4 # Extract residue names and inverse values
#       5 residues = [res for res, _ in sorted_items]
# ----> 6 R1_values = [1.0 / vals['T1']['value'] if 'T1' in vals else float('nan') for _, vals in sorted_items]
#       7 R2_values = [1.0 / vals['T2']['value'] if 'T2' in vals else float('nan') for _, vals in sorted_items]
#       8 hetNOE_values = [vals['hetNOE']['value'] if 'hetNOE' in vals else float('nan') for _, vals in sorted_items]
#
# /tmp/ipykernel_168986/2456915880.py in <listcomp>(.0)
#       4 # Extract residue names and inverse values
#       5 residues = [res for res, _ in sorted_items]
# ----> 6 R1_values = [1.0 / vals['T1']['value'] if 'T1' in vals else float('nan') for _, vals in sorted_items]
#       7 R2_values = [1.0 / vals['T2']['value'] if 'T2' in vals else float('nan') for _, vals in sorted_items]
#       8 hetNOE_values = [vals['hetNOE']['value'] if 'hetNOE' in vals else float('nan') for _, vals in sorted_items]
#
# TypeError: 'float' object is not subscriptable

# %%
data = exp_spin_relaxation_times

# Function to extract data for plotting
def extract_data(field):
    residues = []
    values = []
    errors = []
    for res, val in data[field].items():
        residues.append(res)
        if field in ['T1', 'T2']:
            values.append(1 / val['value'])
            errors.append(val['error'] / (val['value'] ** 2))
        else:
            values.append(val['value'])
            errors.append(val['error'])
    return residues, values, errors

# Plotting
fig, axs = plt.subplots(3, 1, figsize=(14, 12), sharex=True)
fields = ['T1', 'T2', 'hetNOE']
titles = ['1/T1 (s^-1)', '1/T2 (s^-1)', 'hetNOE']

for ax, field, title in zip(axs, fields, titles):
    residues, values, errors = extract_data(field)
    ax.errorbar(residues, values, yerr=errors, fmt='o', ecolor='gray', capsize=3, markersize=5)
    ax.set_ylabel(title)
    ax.grid(True)

axs[-1].set_xticks(range(len(residues)))
axs[-1].set_xticklabels(residues, rotation=90)
axs[-1].set_xlabel('Residue')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_168986/358534253.py in <module>
#      22
#      23 for ax, field, title in zip(axs, fields, titles):
# ---> 24     residues, values, errors = extract_data(field)
#      25     ax.errorbar(residues, values, yerr=errors, fmt='o', ecolor='gray', capsize=3, markersize=5)
#      26     ax.set_ylabel(title)
#
# /tmp/ipykernel_168986/358534253.py in extract_data(field)
#       6     values = []
#       7     errors = []
# ----> 8     for res, val in data[field].items():
#       9         residues.append(res)
#      10         if field in ['T1', 'T2']:
#
# KeyError: 'T1'

# %%
if my_dict.get('res') == 'HIP':
    my_dict['res'] = 'HIS'
